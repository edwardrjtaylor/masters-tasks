# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
from scipy.signal import find_peaks

def top(x,a,b,h): return h if a<x<b else 0


#peak_indices = scipy.signal.find_peaks(x,threshold=peaknum,distance=peaksep,width=peakwidth)

x = ([0,30,3,5,7,9,15,5,19,24,4,6,20,13,18])
#x=np.linspace(0,10)
plt.plot(x,[top(xi,5,7,2) for xi in x])

# %%
#Have to set up array so the value at 0 is where the step is
value = np.linspace(-10,10,100)
#a and b are the heights of the step function
#w is the width of the step function
#s is the horizontal displacement
w=5
a=0.5
b=0.5
h=5
s=20
plt.plot(value,np.heaviside(value, a))
plt.plot(value,-np.heaviside(value-w, b),'k')
plt.show()
plt.plot(value+s,top_hat(value,a,b,w,s,h))
plt.show()
#Can differentiate Heaviside to get Dirac Delta
